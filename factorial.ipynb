# %%
# Python code to demonstrate naive method 
# to compute factorial 

n = 500
fact = 1
  
for i in range(1,n+1): 
    fact = fact * i 
      
print ("The factorial of 500 is : ",end="") 
print (fact)
# Out:
# The factorial of 500 is : ...
