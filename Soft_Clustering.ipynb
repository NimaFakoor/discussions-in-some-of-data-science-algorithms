# %% [markdown]
# # Introduction

# %% [markdown]
# ![information-10-00059-g001.webp](data:image/webp;base64,...)

# %% [markdown]
# ![A-basic-taxonomy-of-clustering-algorithms.png](data:image/png;base64,...)

# %% [markdown]
# ![2020-10-30-clustering-11-hard-soft-clustering.png](data:image/png;base64,...)

# %% [markdown]
# ![An-example-of-hard-and-soft-clustering-in-a-toy-example-containing-7-nodes-A-Hard.png](data:image/png;base64,...)

# %% [markdown]
# ![The-taxonomy-of-different-clustering-algorithms-11-24.png](data:image/png;base64,...)![Taxonomy-of-clustering-algorithms.png](data:image/png;base64,...)

# %% [markdown]
# ![clustering-in-machine-learning.png](data:image/png;base64,...)![association-under-unsupervised-learning.png](data:image/png;base64,...)

# %% [markdown]
# # Implementation

# %%
# <~>

# %% [markdown]
# https://github.com/saniikakulkarni/Gaussian-Mixture-Model-from-scratch/blob/main/Gaussian_Mixture_Model_from_scratch.ipynb
#
# https://www.oranlooney.com/post/ml-from-scratch-part-5-gmm/
#
# https://github.com/TejasV58/Fuzzy-C-means-from-scratch
#
#
# https://towardsdatascience.com/fuzzy-c-means-clustering-with-python-f4908c714081
#
# https://pythonhosted.org/scikit-fuzzy/auto_examples/plot_cmeans.html
#
# https://sandipanweb.wordpress.com/2017/03/19/hard-soft-clustering-with-k-means-weighted-k-means-and-gmm-em/
